# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorOmondi1997/visualizing_us_worst_drivers/blob/master/visualizing_us_worst_drivers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Looking at FiveThirtyEight's data on which US State has the worst drivers. The data set includes summary level information about fatal accidents as well as insurance premiums for each state as of 2010.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('https://raw.githubusercontent.com/VictorOmondi1997/visualizing_us_worst_drivers/master/us_worst_drivers.csv')
df.head()
# Out:
#         State  fatal_collisions  ...  insurance_losses  Region
# 0     Alabama              18.8  ...            145.08   South
# 1      Alaska              18.1  ...            133.93    West
# 2     Arizona              18.6  ...            110.35    West
# 3    Arkansas              22.4  ...            142.39   South
# 4  California              12.0  ...            165.63    West
#
# [5 rows x 9 columns]

# %% [markdown]
# # Regression plot
#
# # regression plot of premiums vs. insurance_losses

# %%
sns.regplot(data=df, x='insurance_losses', y='premiums')
plt.show()

# %%
sns.lmplot(data=df, x='insurance_losses', y='premiums')
plt.show()

# %% [markdown]
# This data set includes geographic information by state and area. It might be interesting to see if there is a difference in relationships based on the `Region` of the country.

# %%
sns.lmplot(data=df, x='insurance_losses', y='premiums', hue='Region')
plt.show()

# %% [markdown]
# The results are bit difficult to read. Maybe using multiple lines is not the best approach. Let's try another one.

# %%
sns.lmplot(data=df, x='insurance_losses', y='premiums', row='Region')
plt.show()

# %% [markdown]
# # a scatter plot for fatal_collisions and premiums

# %%
g = sns.PairGrid(df, vars=["fatal_collisions", "premiums"])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
plt.show()

# %%
sns.pairplot(df, vars=['fatal_collisions', 'premiums'], kind='scatter', hue='Region', palette='RdBu', diag_kws={'alpha':0.5})
plt.show()

# %%
sns.pairplot(df, x_vars=["fatal_collisions_speeding", "fatal_collisions_alc"], y_vars=['premiums', 'insurance_losses'], kind='scatter', hue='Region', palette='husl')
plt.show()

# %% [markdown]
# # Relationships between insurance_losses and premiums

# %%
sns.pairplot(df, vars=["insurance_losses", "premiums"], kind='reg', diag_kind='kde', hue='Region', palette='BrBG', height=10)
plt.show()
